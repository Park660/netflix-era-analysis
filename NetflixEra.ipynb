# %%
print('santhosh')
# Out:
# santhosh

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('netflix_era.csv')

# %%
df
# Out:
#       content_id                    title content_type     genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       release_year      country  language  watch_hours  rating release_month  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
df2=pd.read_csv('netflix_subscribers.csv')

# %% [markdown]
# df2

# %%
df3=pd.read_csv('netflix_revenue.csv')

# %%
df3
# Out:
#     year  revenue_billion_usd
# 0   2007                 1.20
# 1   2008                 1.36
# 2   2009                 1.67
# 3   2010                 2.16
# 4   2011                 3.20
# 5   2012                 3.61
# 6   2013                 4.37
# 7   2014                 5.50
# 8   2015                 6.78
# 9   2016                 8.83
# 10  2017                11.69
# 11  2018                15.79
# 12  2019                20.15
# 13  2020                24.99
# 14  2021                29.70
# 15  2022                31.60
# 16  2023                33.70
# 17  2024                35.40
# 18  2025                36.20

# %%
df2
# Out:
#     year  subscribers_million
# 0   2007                  7.5
# 1   2008                  9.4
# 2   2009                 12.3
# 3   2010                 16.0
# 4   2011                 20.2
# 5   2012                 25.0
# 6   2013                 33.4
# 7   2014                 41.4
# 8   2015                 57.4
# 9   2016                 79.9
# 10  2017                 99.0
# 11  2018                124.3
# 12  2019                151.0
# 13  2020                182.9
# 14  2021                214.0
# 15  2022                230.7
# 16  2023                247.2
# 17  2024                257.9
# 18  2025                260.0

# %%
df.columns
# Out:
# Index(['content_id', 'title', 'content_type', 'genre', 'release_year',
#        'country', 'language', 'watch_hours', 'rating', 'release_month', 'year',
#        'subscribers_million', 'revenue_billion_usd'],
#       dtype='object')

# %%
df.drop(columns=['subscribers_million','revenue_billion_usd'],inplace=True)

# %%
df
# Out:
#       content_id                    title content_type     genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       release_year      country  language  watch_hours  rating release_month  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
df.columns=df.columns.str.replace('_','f')

# %%
df
# Out:
#       contentfid                    title contentftype     genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       releasefyear      country  language  watchfhours  rating releasefmonth  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
df.columns=df.columns.str.replace('f','_')

# %%
df
# Out:
#       content_id                    title content_type     genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       release_year      country  language  watch_hours  rating release_month  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
df.columns=df.columns.str.title()

# %%
df
# Out:
#       Content_Id                    Title Content_Type     Genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       Release_Year      Country  Language  Watch_Hours  Rating Release_Month  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#       content_id                    title content_type     genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       release_year      country  language  watch_hours  rating release_month  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
pip install sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------  2.1/2.1 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 8.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
# ...

# %%
pip install sqlalchemy pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as sal
engine=sal.create_engine('mssql+pyodbc://SANTHOSH\\SQLEXPRESS/StudentsDB?driver=ODBC+Driver+17+for+SQL+Server')
conn=engine.connect()

# %%
df.to_sql('df_netflix_era.csv',con=conn,index=False,if_exists='replace')
df2.to_sql('df2_netflix_subscribers',con=conn,index=False,if_exists='replace')
df3.to_sql('df3_netflix_revenue',con=conn,index=False,if_exists='replace')
# Out:
# 19

# %%
conn.close()

# %%
df

# %%
df=pd.read_csv('netflix_era.csv')

# %%
df
# Out:
#       content_id                    title content_type     genre  \
# 0              1                Narcos S1   Web Series     Drama
# 1              2  Avengers Endgame (2018)        Movie    Horror
# 2              3       Game of Thrones S1   Web Series    Action
# 3              4          City of Lies S1   Web Series    Action
# 4              5     KGF Chapter 2 (2017)        Movie  Thriller
# ...          ...                      ...          ...       ...
# 9995        9996       Game of Thrones S1   Web Series    Action
# 9996        9997                  Dark S1   Web Series  Thriller
# 9997        9998      Cold Pursuit (2012)        Movie    Sci-Fi
# 9998        9999                  Dark S3   Web Series  Thriller
# 9999       10000   Shadow Protocol (2025)        Movie    Action
#
#       release_year      country  language  watch_hours  rating release_month  \
# 0             2012        India   English    183910448     4.8         April
# ...

# %%
import sqlalchemy as sal
engine=sal.create_engine
conn=engine.connect()

# %%
df.to_sql('df_netflix_era.csv',con=conn,index=False,if_exists='replace')
df2.to_sql('df2_netflix_subscribers',con=conn,index=False,if_exists='replace')
df3.to_sql('df3_netflix_revenue',con=conn,index=False,if_exists='replace')
# Out:
# 19

# %%
df.to_sql('df_netflix_era',con=conn,index=False,if_exists='replace')
df2.to_sql('df2_netflix_subscribers',con=conn,index=False,if_exists='replace')
df3.to_sql('df3_netflix_revenue',con=conn,index=False,if_exists='replace')
# Out:
# 19
